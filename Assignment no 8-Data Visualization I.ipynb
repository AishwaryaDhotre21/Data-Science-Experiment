# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=sns.load_dataset('titanic')

# %%
dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %% [markdown]
# # Distributional Plots
#
# Distributional plots, as the name suggests are type of plots that show the statistical distribution of data.

# %% [markdown]
# #  Dist Plot
#
# The distplot() shows the histogram distribution of data for a single column.

# %%
sns.displot(dataset['fare'],kind="hist")

# %% [markdown]
# Distribution of Fare coloumn for passengers using histogram

# %%
sns.displot(dataset['fare'],kind="kde")

# %% [markdown]
# You can clearly see that for more than 700 passengers, the ticket price is between 0 and 50.

# %%
sns.distplot(dataset['fare'],kde=False,bins=10)
# Out:
# C:\Users\Aishwarya\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare'>

# %% [markdown]
# # Joint Plot

# %%
sns.jointplot(x='age',y='fare',data=dataset)

# %% [markdown]
# There is no correlation between the age and fare

# %% [markdown]
# # Pair Plot
#
#   The paitplot() is a type of distribution plot that basically plots a joint plot for all the possible combination of numeric and Boolean columns in your dataset

# %%
sns.pairplot(dataset)
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.pairplot(dataset,hue='sex')
# Out:
# C:\Users\Aishwarya\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Categorical Plots
#
# Categorical plots, as the name suggests are normally used to plot categorical data. The categorical plots plot the values in the categorical column against another categorical column or a numeric column.

# %% [markdown]
# # Bar Plot
#
# is used to display the mean value for each value in a categorical column, against a numeric column.

# %%
sns.barplot(x='sex',y='age',data=dataset)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# Avearage age of male passangesrs on an average is 30 and female on an average is 35

# %%
sns.barplot(x='sex', y='age', data=dataset, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# std deviation for the age of male is little bit greater than 14 and of female is between 13 to 14

# %%
sns.barplot(x='sex',y='age',data=dataset,hue='embarked')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# avg age of male and female passengers in a particular embarked category

# %%
sns.barplot(x='sex',y='age',data=dataset,hue='class')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.barplot(x='sex',y='age',data=dataset,hue='alone')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.barplot(x='sex',y='age',data=dataset,hue='survived')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# avg age of survived and died male and female passengers

# %%
sns.barplot(x='survived',y='age',data=dataset,hue='sex')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
sns.barplot(x='class',y='age',data=dataset,hue='sex')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# avg age of male and female passengers in a particular class

# %%
sns.barplot(x='class',y='age',data=dataset,hue='embarked')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# avg age of a passengers in a particular class and their epration according to a particular embarked

# %%
sns.barplot(x='class',y='fare',data=dataset,hue='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='fare'>

# %% [markdown]
# avg fare of male,female and childrens of a particular class

# %% [markdown]
# # Count Plot
#
# it displays the count of the categories in a specific column

# %%
sns.countplot(x='sex',data=dataset)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# countplot is showing here the count of male is greater than 550 but below 600 and count of female is nearly about 300

# %%
sns.countplot(x='sex',data=dataset,hue='survived')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# count of survived and died male and female passengers

# %%
sns.countplot(x='survived',data=dataset,hue='sex')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %% [markdown]
# the above both bar plot shows the male and female survived count

# %%
dataset.groupby('survived')['embarked'].value_counts()
# Out:
# survived  embarked
# 0         S           427
#           C            75
#           Q            47
# 1         S           217
#           C            93
#           Q            30
# Name: embarked, dtype: int64

# %%
sns.histplot(x='survived',data=dataset,hue='embarked')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='Count'>

# %% [markdown]
# distribution of survived people at particular embarked

# %%
dataset.groupby('sex')['embarked'].value_counts()
# Out:
# sex     embarked
# female  S           203
#         C            73
#         Q            36
# male    S           441
#         C            95
#         Q            41
# Name: embarked, dtype: int64

# %%
sns.histplot(x='sex',data=dataset,hue='embarked')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Count'>

# %% [markdown]
# count of male and female passengers of particular embarked

# %%
sns.countplot(x='class',data=dataset,hue='embarked')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x='class',data=dataset,hue='sex')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x='class',data=dataset,hue='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x='class',data=dataset,hue='deck')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x='sex',data=dataset,hue='deck')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='survived',data=dataset,hue='deck')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='sex',data=dataset,hue='parch')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.barplot(x='class',y='survived',data=dataset,hue='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
sns.countplot(x='sibsp',data=dataset)
# Out:
# <AxesSubplot:xlabel='sibsp', ylabel='count'>

# %%
sns.countplot(x='sibsp',data=dataset,hue='sex')
# Out:
# <AxesSubplot:xlabel='sibsp', ylabel='count'>

# %%
sns.countplot(x='sibsp',data=dataset,hue='who')
# Out:
# <AxesSubplot:xlabel='sibsp', ylabel='count'>

# %%
sns.histplot(x='survived',y='class',data=dataset,hue='who')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='class'>

# %%
sns.histplot(x='class',y='survived',data=dataset,hue='who')
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
sns.countplot(x='survived',data=dataset,hue='who')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %% [markdown]
# # catplot

# %%
sns.catplot(x ='embarked', hue ='survived',kind ='count', col ='pclass', data = dataset)

# %%
sns.catplot(x ='who', hue ='survived',kind ='count', col ='pclass', data = dataset)

# %% [markdown]
# count of survived male,female and children at a particular class

# %%
sns.catplot(x ='sex', hue ='survived',kind ='count', col ='pclass', data = dataset)

# %%
sns.catplot(x ='embarked', hue ='survived',kind ='count', col ='pclass', data = dataset)

# %%
sns.catplot(x ='sex', hue ='survived',kind ='count', col ='who', data = dataset)

# %%
sns.catplot(x ='who', hue ='survived',kind ='count', col ='sex', data = dataset)

# %%
sns.catplot(x="alive", col="deck", col_wrap=4,data=dataset[dataset.deck.notnull()],kind="count", height=2.5, aspect=.8)

# %%
sns.catplot(x="sex", col="deck", col_wrap=4,data=dataset[dataset.deck.notnull()],kind="count", height=3.5, aspect=.8,hue='survived')

# %% [markdown]
# # Write a code to check how the price of the ticket (column name: 'fare') for each passenger is distributed by plotting a histogram

# %%
sns.distplot(dataset['fare'], kde=False)
# Out:
# C:\Users\Aishwarya\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='fare'>

# %%
sns.distplot(dataset['fare'], kde=True)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Density'>

# %%
sns.histplot(x='fare',y='sex',data=dataset)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='sex'>

# %%
sns.histplot(x='sex',y='fare',data=dataset)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='fare'>

# %%
sns.histplot(x='who',y='fare',data=dataset)
# Out:
# <AxesSubplot:xlabel='who', ylabel='fare'>

# %%
sns.histplot(x='pclass',y='fare',data=dataset)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='fare'>

# %%
sns.histplot(x='fare',data=dataset,bins=5,hue='sex')
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>
