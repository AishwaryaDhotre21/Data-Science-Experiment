# %%
#importing the dataset
#importing the required libraries
#website https://www.kaggle.com/benroshan/factors-affecting-campus-placement?select=Placement_Data_Full_Class.csv
import pandas as pd

# %%
#read csv file
df1=pd.read_csv('Placement_Data_Full_Class.csv')

# %%
df1.size
# Out:
# 3225

# %%
df1.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
#shows the not-null values count in each coloumn
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
#display the count of null values
df1.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
#displays the null values of a salary coloumn
df1['salary'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 210    False
# 211    False
# 212    False
# 213    False
# 214     True
# Name: salary, Length: 215, dtype: bool

# %%
#drop the all rows containing the null values from df1 dataset and assign new values to new_df dataset
new_df=df1.dropna()

# %%
#dataset without the null values
new_df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
new_df.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148 entries, 0 to 213
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           148 non-null    int64
#  1   gender          148 non-null    object
#  2   ssc_p           148 non-null    float64
#  3   ssc_b           148 non-null    object
#  4   hsc_p           148 non-null    float64
#  5   hsc_b           148 non-null    object
#  6   hsc_s           148 non-null    object
#  7   degree_p        148 non-null    float64
#  8   degree_t        148 non-null    object
#  9   workex          148 non-null    object
#  10  etest_p         148 non-null    float64
#  11  specialisation  148 non-null    object
#  12  mba_p           148 non-null    float64
#  13  status          148 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 18.5+ KB

# %%
#convert the dataset to csv file
new_df.to_csv('CSV_file_without_any_null_values.csv')

# %%
#drop all coloumns containing the null values and assign data to new dataset
new_df1=df1.dropna(axis=1,inplace=False)

# %%
#Here the one column i.e Salary is dropped which was having the null values
new_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 23.6+ KB

# %%
#Now, the dropna(inplace = True) will NOT return a new DataFrame, but it will remove all rows containg NULL values from the original DataFrame.
df1.dropna(axis=1,inplace=True)

# %%
df1.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# dtype: int64

# %%
df2=pd.read_csv('Placement_Data_Full_Class.csv')
# replace all na values with -9999 and assign the values to new data frame
new_df2=df2.fillna(-99999)

# %%
#salary column of the data set containing null values replaced -9999
new_df2['salary']
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3      -99999.0
# 4      425000.0
#          ...
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 213    204000.0
# 214    -99999.0
# Name: salary, Length: 215, dtype: float64

# %%
new_df2.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
df2['salary']
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           NaN
# 4      425000.0
#          ...
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 213    204000.0
# 214         NaN
# Name: salary, Length: 215, dtype: float64

# %%
df2
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#looping over the values in the data frame
for i in df2.index:
     if(df2.loc[i,"ssc_p"]==79.00):
             f=df2.loc[i,"salary"]
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# 210000.0

# %%
df2['salary']
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           NaN
# 4      425000.0
#          ...
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 213    204000.0
# 214         NaN
# Name: salary, Length: 215, dtype: float64

# %%
#fill na values with strings
new_df4=df2.fillna("Data Missing")
new_df4
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status        salary
# ...

# %%
df2.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
#new_df5=df2.fillna(df2.mean(''))
new_df5=df2.fillna(df2.mean())

# %%
new_df5['salary']
# Out:
# 0      270000.000000
# 1      200000.000000
# 2      250000.000000
# 3      288655.405405
# 4      425000.000000
#            ...
# 210    400000.000000
# 211    275000.000000
# 212    295000.000000
# 213    204000.000000
# 214    288655.405405
# Name: salary, Length: 215, dtype: float64

# %%
#reload new data set
df11=pd.read_csv('StudentsPerformance1.csv')

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Roll_no                      1002 non-null   int64
#  1   gender                       1002 non-null   object
#  2   race/ethnicity               1002 non-null   object
#  3   parental level of education  1002 non-null   object
#  4   lunch                        1002 non-null   object
#  5   test preparation course      1002 non-null   object
#  6   math score                   1002 non-null   int64
#  7   reading score                1002 non-null   int64
#  8   writing score                1002 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 70.6+ KB

# %%
#duplicate rows count
df11.duplicated().sum()
# Out:
# 2

# %%
df11[1:20].duplicated()
# Out:
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# dtype: bool

# %%
#drop duplicated rows
new_df6=df11.drop_duplicates()

# %%
new_df6.duplicated().sum()
# Out:
# 0

# %%
new_df6
# Out:
#       Roll_no  gender race/ethnicity parental level of education  \
# 0           1  female        group B           bachelor's degree
# 1           2  female        group C                some college
# 2           3  female        group B             master's degree
# 3           4    male        group A          associate's degree
# 4           5    male        group C                some college
# ...       ...     ...            ...                         ...
# 997       996  female        group E             master's degree
# 998       997    male        group C                 high school
# 999       998  female        group C                 high school
# 1000      999  female        group D                some college
# 1001     1000  female        group D                some college
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none          72             72
# ...

# %%
#getting the mean of a particular coloumn
df11['math score'].mean()
# Out:
# 65.8872255489022

# %%
#getting the minimum value of a particular coloumn
df11['math score'].min()
# Out:
# 0

# %%
#finding the roll numbers of a students who got 0 marks in maths and find the count of those students
li=[]
count=0
for i in df11.index:
    if df11.loc[i,"math score"]==0:
        li.append(df11.loc[i,"Roll_no"])
        count=count+1
        
        
print('Roll no of students who scored zero(0) marks in maths:',li,'\nAnd the total count of those students',count)
# Out:
# Roll no of students who scored zero(0) marks in maths: [4, 17, 24, 60]
# And the total count of those students 4

# %%
df11['math score']
# Out:
# 0       72
# 1       69
# 2       90
# 3        0
# 4       76
#         ..
# 997     88
# 998     62
# 999     59
# 1000    68
# 1001    77
# Name: math score, Length: 1002, dtype: int64

# %%
#replace the maths score of the students who scored 0 with the mean of the maths score 
li=[]
count=0
for i in df11.index:
    if df11.loc[i,"math score"]==0:
        df11.loc[i,"math score"]=df11["math score"].mean()
        li.append(df11.loc[i,"Roll_no"])
        count=count+1
        

        
print('Roll no of students whoes scored get replaced :',li,'\nAnd the total count of those students',count)
# Out:
# Roll no of students whoes scored get replaced : [4, 17, 24, 60]
# And the total count of those students 4

# %%
#the score of the students whoes data got replaced
for i in li:
     print(df11.loc[i,['math score']])
# Out:
# math score    76
# Name: 4, dtype: object
# math score    65.953
# Name: 17, dtype: object
# math score    44
# Name: 24, dtype: object
# math score    58
# Name: 60, dtype: object

# %%
df11['math score']
# Out:
# 0       72.000000
# 1       69.000000
# 2       90.000000
# 3       65.887226
# 4       76.000000
#           ...
# 997     88.000000
# 998     62.000000
# 999     59.000000
# 1000    68.000000
# 1001    77.000000
# Name: math score, Length: 1002, dtype: float64

# %%
df12=pd.read_csv('StudentsPerformance1.csv')
df12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Roll_no                      1002 non-null   int64
#  1   gender                       1002 non-null   object
#  2   race/ethnicity               1002 non-null   object
#  3   parental level of education  1002 non-null   object
#  4   lunch                        1002 non-null   object
#  5   test preparation course      1002 non-null   object
#  6   math score                   1002 non-null   int64
#  7   reading score                1002 non-null   int64
#  8   writing score                1002 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 70.6+ KB

# %%
#delete the rows from data frame who scored 0 in the maths
li=[]
count=0
for i in df12.index:
    if df12.loc[i,"math score"]==0:
        new_Df7=df12.drop([i],inplace=True)
        li.append(df11.loc[i,"Roll_no"])
        count=count+1
        

        
print('Roll no of students whoes data get deleted from the data frame:',li,'\nAnd the total count of those students',count)
# Out:
# Roll no of students whoes data get deleted from the data frame: [4, 17, 24, 60]
# And the total count of those students 4

# %%
df12
# Out:
#       Roll_no  gender race/ethnicity parental level of education  \
# 0           1  female        group B           bachelor's degree
# 1           2  female        group C                some college
# 2           3  female        group B             master's degree
# 4           5    male        group C                some college
# 5           6  female        group B          associate's degree
# ...       ...     ...            ...                         ...
# 997       996  female        group E             master's degree
# 998       997    male        group C                 high school
# 999       998  female        group C                 high school
# 1000      999  female        group D                some college
# 1001     1000  female        group D                some college
#
#              lunch test preparation course  math score  reading score  \
# 0         standard                    none          72             72
# ...

# %% [markdown]
# Apply data transformations on at least one of the variables. The purpose of this transformation should be one of the following reasons: to change the scale for better understanding of the variable, to convert a non-linear relation into a linear one, or to decrease the skewness and convert the distribution into a normal distribution.

# %%
#load dataset and import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df21=pd.read_csv('StudentsPerformance.csv')

# %%
df21
# Out:
#      Roll_no  gender race/ethnicity parental level of education         lunch  \
# 0          1  female        group B           bachelor's degree      standard
# 1          2  female        group C                some college      standard
# 2          3  female        group B             master's degree      standard
# 3          4    male        group A          associate's degree  free/reduced
# 4          5    male        group C                some college      standard
# ..       ...     ...            ...                         ...           ...
# 995      996  female        group E             master's degree      standard
# 996      997    male        group C                 high school  free/reduced
# 997      998  female        group C                 high school  free/reduced
# 998      999  female        group D                some college      standard
# 999     1000  female        group D                some college  free/reduced
#
# ...

# %%
df21.skew(axis=0,skipna=True)
# Out:
# Roll_no            0.000000
# math score        -0.278935
# reading score     -0.259105
# writing score     -0.289444
# writing score.1   -0.289444
# dtype: float64

# %%
print(df21['math score'].skew())
print(df21['math score'].mean())
print(df21['math score'].median())
# Out:
# -0.27893514909431694
# 66.089
# 66.0

# %%
df21.skew(axis=1,skipna=True)
# Out:
# 0     -2.230683
# 1     -1.973326
# 2     -2.225097
# 3     -1.832651
# 4     -2.227690
#          ...
# 995    2.235528
# 996    2.235778
# 997    2.235490
# 998    2.235526
# 999    2.235561
# Length: 1000, dtype: float64

# %%
import statistics
print(df21['math score'].skew())
print(df21['math score'].mean())
print(df21['math score'].mode())
print(df21['math score'].median())
df21['math score'].hist()
plt.xlabel('Maths score')
plt.ylabel('Students')
plt.title('Histomgram')
# Out:
# -0.27893514909431694
# 66.089
# 0    65
# dtype: int64
# 66.0
# Text(0.5, 1.0, 'Histomgram')

# %%
import statistics
print(df21['math score'].skew())
print(df21['math score'].mean())
print(df21['math score'].mode())
print(df21['math score'].median())
# Out:
# -0.27893514909431694
# 66.089
# 0    65
# dtype: int64
# 66.0

# %%
#replace the maths score of the students who scored 0 with the mean of the maths score 
li=[]
count=0
for i in df21.index:
    if df21.loc[i,"math score"]<=40:
        df21.loc[i,"math score"]=df21["math score"].mean()
        li.append(df21.loc[i,"Roll_no"])
        count=count+1
        

        
print('Roll no of students whoes scored get replaced :',li,'\nAnd the total count of those students',count)
# Out:
# Roll no of students whoes scored get replaced : [8, 10, 12, 18, 34, 56, 60, 62, 70, 77, 92, 146, 212, 218, 285, 299, 328, 339, 340, 364, 384, 385, 456, 467, 505, 528, 529, 553, 556, 576, 597, 602, 608, 617, 621, 684, 742, 778, 786, 788, 841, 843, 845, 863, 896, 897, 903, 922, 981, 987]
# And the total count of those students 50

# %%
df21['math score'].hist()
plt.ylabel('Students')
plt.title('Histomgram')

# %%
print(df21['math score'].skew())
print(df21['math score'].mean())
print(df21['math score'].median())

# %%
#replace the maths score of the students who scored 0 with the mean of the maths score 
li=[]
count=0
for i in df21.index:
    if df21.loc[i,"math score"]>=80:
        df21.loc[i,"math score"]=df21["math score"].mean()
        li.append(df21.loc[i,"Roll_no"])
        count=count+1
        

        
print('Roll no of students whoes scored get replaced :',li,'\nAnd the total count of those students',count)

# %%
df21['math score'].hist()
plt.xlabel('Maths score')
plt.ylabel('Students')
plt.title('Histomgram')
plt.show()

# %%
print(df21['math score'].skew())
print(df21['math score'].mean())
print(df21['math score'].median())

# %%
#replace the maths score of the students who scored 0 with the mean of the maths score 
li=[]
count=0
for i in df21.index:
    if df21.loc[i,"math score"]<=60:
        df21.loc[i,"math score"]=70
        li.append(df21.loc[i,"Roll_no"])
        count=count+1
        

        
print('Roll no of students whoes scored get replaced :',li,'\nAnd the total count of those students',count)

# %%
df21['math score'].hist()
plt.xlabel('Maths score')
plt.ylabel('Students')
plt.title('Histomgram')

# %%
print(df21['math score'].skew())
print(df21['math score'].mean())
print(df21['math score'].median())

# %%
#replace the maths score of the students who scored 0 with the mean of the maths score 
li=[]
count=0
for i in df21.index:
        df21.loc[i,"math score"]=70
        li.append(df21.loc[i,"Roll_no"])
        count=count+1
        

        
print('Roll no of students whoes scored get replaced :',li,'\nAnd the total count of those students',count)

# %%
df21['math score'].hist()
plt.xlabel('Maths score')
plt.ylabel('Students')
plt.title('Histomgram')

# %%
print(df21['math score'].skew())
print(df21['math score'].mean())
print(df21['math score'].median())
